# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=10, style="whitegrid")





# Import data using datetime and no data value
hydrometric_2001_2020_daily = pd.read_csv("C:/Users/mojta/OneDrive/Desktop/csv/2001.csv",
                                      parse_dates=[0],
                                      index_col=[0],
                                      na_values=['999.99'])

# View first few rows
hydrometric_2001_2020_daily.head()




#import pandas as pd
#
#print(type(file_red))
#print(file_red)
#file_red=file_red.resample('D').sum()
# Out:
#                 FLOW
# DATA
# 2001-01-02  6.445909
# 2001-01-02  5.399747
# 2001-01-02  4.615125
# 2001-01-03  6.184368
# 2001-01-03  5.138206

# %%
hydrometric_2001_2020_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1687 entries, 2001-01-02 to 2001-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FLOW    1687 non-null   float64
# dtypes: float64(1)
# memory usage: 26.4 KB

# %%
hydrometric_2001_2020_daily.describe()
# Out:
#               FLOW
# count  1687.000000
# mean     13.925471
# std      13.924836
# min       0.430477
# 25%       3.830504
# 50%       8.015152
# 75%      20.961408
# max      63.461742

# %%
hydrometric_2001_2020_daily.index
# Out:
# DatetimeIndex(['2001-01-02', '2001-01-02', '2001-01-02', '2001-01-03',
#                '2001-01-03', '2001-01-03', '2001-01-04', '2001-01-04',
#                '2001-01-05', '2001-01-05',
#                ...
#                '2001-12-27', '2001-12-27', '2001-12-28', '2001-12-28',
#                '2001-12-28', '2001-12-29', '2001-12-29', '2001-12-29',
#                '2001-12-29', '2001-12-30'],
#               dtype='datetime64[ns]', name='DATA', length=1687, freq=None)

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 10))

# Add x-axis and y-axis
ax.scatter(hydrometric_2001_2020_daily.index.values,
           hydrometric_2001_2020_daily['FLOW'],
           color='purple')

ax.tick_params(axis='both', which='major', labelsize=10)

plt.show()
